# %%
import pandas as pd

# %%
import seaborn as sns

# %%
credit = pd.read_csv('/Users/johnmiller/Downloads/default of credit card clients.csv')

# %% [markdown]
# # Preparation

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
import numpy as np

# %%
credit['age_bin'] = pd.cut(credit['AGE'], bins=np.linspace(20, 79, 7))

# %%
credit.dtypes
# Out:
# ID                               int64
# LIMIT_BAL                        int64
# SEX                              int64
# EDUCATION                        int64
# MARRIAGE                         int64
# AGE                              int64
# PAY_0                            int64
# PAY_2                            int64
# PAY_3                            int64
# PAY_4                            int64
# PAY_5                            int64
# PAY_6                            int64
# BILL_AMT1                        int64
# BILL_AMT2                        int64
# BILL_AMT3                        int64
# BILL_AMT4                        int64
# BILL_AMT5                        int64
# BILL_AMT6                        int64
# PAY_AMT1                         int64
# PAY_AMT2                         int64
# PAY_AMT3                         int64
# PAY_AMT4                         int64
# PAY_AMT5                         int64
# PAY_AMT6                         int64
# ...

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bin'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
# why is 500,000 so visible, when the majority appear to be 0-200,000 and plurality 0-100,000?

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
#plot varies from example, less shading

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bin'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %% [markdown]
# ##Correlation and Covariance

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
#Corr between:
##Limit and Bill/Pay amt, repayment, education, default;
##Repayment and Default
##Limit and default
###Education and repayment, age, limit, and 

#Not useful:
##Sex
##Age

# %%
corrMat.info
# Out:
# <bound method DataFrame.info of                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# ...

# %%
corrMat.sort_values('default payment next month',axis=0)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# PAY_AMT1                    0.009742   0.195236 -0.000242  -0.037456
# PAY_AMT2                    0.008406   0.178408 -0.001391  -0.030038
# PAY_AMT4                    0.007793   0.203242 -0.002229  -0.038218
# PAY_AMT3                    0.039151   0.210167 -0.008597  -0.039943
# PAY_AMT5                    0.000652   0.217202 -0.001667  -0.040358
# PAY_AMT6                    0.003000   0.219595 -0.002766  -0.037200
# SEX                         0.018497   0.024755  1.000000   0.014232
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# BILL_AMT2                   0.017982   0.278314 -0.031183   0.018749
# BILL_AMT3                   0.024354   0.283236 -0.024563   0.013002
# ID                          1.000000   0.026179  0.018497   0.039177
# ...

# %%
corrMatdef1 = corrMat['default payment next month']

# %%
corrMatdef1.sort_values(ascending=False)
# Out:
# default payment next month    1.000000
# PAY_0                         0.324794
# PAY_2                         0.263551
# PAY_3                         0.235253
# PAY_4                         0.216614
# PAY_5                         0.204149
# PAY_6                         0.186866
# EDUCATION                     0.028006
# AGE                           0.013890
# BILL_AMT6                    -0.005372
# BILL_AMT5                    -0.006760
# BILL_AMT4                    -0.010156
# ID                           -0.013952
# BILL_AMT3                    -0.014076
# BILL_AMT2                    -0.014193
# BILL_AMT1                    -0.019644
# MARRIAGE                     -0.024339
# SEX                          -0.039961
# PAY_AMT6                     -0.053183
# PAY_AMT5                     -0.055124
# PAY_AMT3                     -0.056250
# PAY_AMT4                     -0.056827
# PAY_AMT2                     -0.058579
# PAY_AMT1                     -0.072929
# ...

# %%
#Repayment, Limit_Bal only things <0.1 over/under 0, next Pay_amts

# %%
corrMatdef2=corrMat[['LIMIT_BAL','PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6','PAY_AMT1']]

# %%
corrMatdef2.sort_values('PAY_0',ascending=False)
# Out:
#                             LIMIT_BAL     PAY_0     PAY_2     PAY_3     PAY_4  \
# PAY_0                       -0.271214  1.000000  0.672164  0.574245  0.538841
# PAY_2                       -0.296382  0.672164  1.000000  0.766552  0.662067
# PAY_3                       -0.286123  0.574245  0.766552  1.000000  0.777359
# PAY_4                       -0.267460  0.538841  0.662067  0.777359  1.000000
# PAY_5                       -0.249411  0.509426  0.622780  0.686775  0.819835
# PAY_6                       -0.235195  0.474553  0.575501  0.632684  0.716449
# default payment next month  -0.153520  0.324794  0.263551  0.235253  0.216614
# BILL_AMT2                    0.278314  0.189859  0.235257  0.237295  0.225816
# BILL_AMT1                    0.285430  0.187068  0.234887  0.208473  0.202812
# BILL_AMT5                    0.295562  0.180635  0.221348  0.225145  0.242902
# BILL_AMT3                    0.283236  0.179785  0.224146  0.227494  0.244983
# ...

# %%
#Nothing of concern noted, all could be safely included in modeling, likely true of PAY_AMT2-6

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                      ID     LIMIT_BAL          SEX     EDUCATION     MARRIAGE  \
# ID         7.500250e+07  2.941664e+07    78.356379    268.154338  -131.452515
# LIMIT_BAL  2.941664e+07  1.683446e+10  1571.050630 -22474.028945 -7323.669658
# SEX        7.835638e+01  1.571051e+03     0.239247      0.005502    -0.008014
# EDUCATION  2.681543e+02 -2.247403e+04     0.005502      0.624651    -0.059184
# MARRIAGE  -1.314525e+02 -7.323670e+03    -0.008014     -0.059184     0.272452
# AGE        1.491057e+03  1.730767e+05    -0.409726      1.275380    -1.992764
# PAY_0     -2.975726e+02 -3.954593e+04    -0.031685      0.093584     0.011683
# PAY_2     -1.162770e+02 -4.603765e+04    -0.041442      0.115025     0.015122
# PAY_3     -1.916922e+02 -4.443225e+04    -0.038694      0.107861     0.020421
# PAY_4     -2.769132e+01 -4.057181e+04    -0.034411      0.100528     0.020213
# PAY_5     -2.178600e+02 -3.667056e+04    -0.030521      0.087340     0.021074
# ...

# %%
sns.catplot('PAY_0',data=credit,kind='count')

# %%
credit.groupby('PAY_0')['PAY_0'].count()
# Out:
# PAY_0
# -2     2759
# -1     5686
#  0    14737
#  1     3688
#  2     2667
#  3      322
#  4       76
#  5       26
#  6       11
#  7        9
#  8       19
# Name: PAY_0, dtype: int64

# %%
#A plurality of payments use revolving credit
#Appears to be normal distribution centered on 0, skewed negative (no cons, paid in full)

# %%
credit = credit.rename(columns={'default payment next month':"DEFAULT"})

# %%
sns.catplot('PAY_0',data=credit,hue='DEFAULT',kind='count')

# %%
#spike of defaults at 2 month payment delay, similar ratio at 3 month

# %%
sns.catplot('PAY_2',data=credit,hue='DEFAULT',kind='count')

# %%
sns.catplot('PAY_3',data=credit,hue='DEFAULT',kind='count')

# %% [markdown]
# ## SEX

# %%
sns.catplot('SEX',data=credit,hue='DEFAULT',kind='count')

# %%
#Males at slight but visibly higher rate

# %% [markdown]
# ## AGE

# %%
sns.lmplot('AGE','DEFAULT',data=credit,hue='SEX')

# %%
#Older males more likely to default? so slight it doesn't appear useful

# %%
#Perhaps a more useful visualization

# %%
sns.catplot('age_bin',data=credit,hue='DEFAULT',kind='count',aspect=2)

# %%
#age bins appears to reflect 30-40 cohort are least likely to default, but still
#unclear value for modeling

# %% [markdown]
# # Education

# %%
sns.lmplot('PAY_0','DEFAULT',data=credit,hue='EDUCATION')

# %%
#grad school less likely to default than HS/Univ??

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: EDUCATION, dtype: int64

# %% [markdown]
# # Marriage

# %%
sns.lmplot('PAY_0','DEFAULT',data=credit,hue='MARRIAGE')

# %%
#"others" martial status 0 seems to be less likely to dfault. other 3 similar

# %%
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64
